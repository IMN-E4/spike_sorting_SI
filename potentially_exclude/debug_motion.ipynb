# %%
# %load_ext autoreload
# %autoreload 2 # what is this for exactly?

# %%
# %matplotlib widget

# %%
import matplotlib.pyplot as plt
from myfigures import plot_drift
from pathlib import Path
import numpy as np

import spikeinterface.full as si
from spikeinterface.sortingcomponents.motion_correction import CorrectMotionRecording

# %%
# main_path = Path('/data2/Neuropixel_recordings/Cerebellum/Anesth_10_01_2023/sorting_cache/2023-01-Rec_10_01_2023_1_g0-full/')
# main_path = Path('/data2/Neuropixel_recordings/Cerebellum/Anesth_10_01_2023/sorting_cache/2023-01-Rec_10_01_2023_2_g0-full/')
main_path = Path('/data2/Neuropixel_recordings/Cerebellum/Anesth_21_01_2023/sorting_cache/2023-01-Rec_21_01_2023_1_g0-full/')

peaks = np.load(main_path / 'peaks.npy')
rec_preprocess = si.load_extractor(main_path / 'preprocess_recording')
peak_locations = np.load(main_path / 'peak_locations.npy')
name = ''
figure_folder = None
motion = np.load(main_path / 'motion.npy')
temporal_bins = np.load(main_path / 'motion_temporal_bins.npy')
spatial_bins = np.load(main_path / 'motion_spatial_bins.npy')

# %%
plot_drift?
# Out:
# Signature:
# plot_drift(
#     peaks,
#     rec_preprocess,
#     peak_locations,
#     name,
#     figure_folder,
#     motion=None,
#     temporal_bins=None,
#     spatial_bins=None,
#     alpha=0.02,
# )
# Docstring: <no docstring>
# File:      ~/python-related/github-repos/spike_sorting_with_samuel/main_scripts/myfigures.py
# Type:      function

# %%
recording_corrected = CorrectMotionRecording(rec_preprocess, motion, temporal_bins, spatial_bins)

# %%
fig, ax = plt.subplots()
ax.plot(temporal_bins, motion)
# Out:
# /home/eduarda/.virtualenvs/py310_si/lib/python3.10/site-packages/ipywidgets/widgets/widget.py:443: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# NavigationToolbar2WebAgg.__init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   super().__init__(**kwargs)
# ...
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plot_drift(peaks, rec_preprocess, peak_locations, name, figure_folder, 
              motion=motion, temporal_bins=temporal_bins, spatial_bins=spatial_bins, alpha=0.002)
# Out:
# /home/eduarda/.virtualenvs/py310_si/lib/python3.10/site-packages/ipywidgets/widgets/widget.py:443: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# NavigationToolbar2WebAgg.__init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   super().__init__(**kwargs)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plot_drift(peaks, recording_corrected, peak_locations, name, figure_folder, 
              motion=motion, temporal_bins=temporal_bins, spatial_bins=spatial_bins, alpha=0.002)
# Out:
# /home/eduarda/.virtualenvs/py310_si/lib/python3.10/site-packages/ipywidgets/widgets/widget.py:443: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# NavigationToolbar2WebAgg.__init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   super().__init__(**kwargs)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
