# %%
# %load_ext autoreload
# %autoreload 2 # what is this for exactly?

# %%
# %matplotlib widget

# %%
import matplotlib.pyplot as plt
from pathlib import Path
import numpy as np

import spikeinterface.full as si

# %%
wv_path = Path('/data2/Anindita/Openephys_Sortings/b13g13/08122022/2023-01-08122022-0to600/waveforms_kilosort2_5/')
we = si.load_waveforms(wv_path)
print(we)
# Out:
# WaveformExtractor: 64 channels - 76 units - 1 segments
#   before:30 after:60 n_per_units:500 - sparse

# %%
si.plot_unit_templates(we, unit_ids=[0])
# Out:
# /home/eduarda/.virtualenvs/py310_si/lib/python3.10/site-packages/ipywidgets/widgets/widget.py:443: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# NavigationToolbar2WebAgg.__init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   super().__init__(**kwargs)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
