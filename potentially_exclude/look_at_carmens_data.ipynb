# %%
import spikeinterface.full as si
# %matplotlib widget

# %%
cd /nas/Neuropixel2_Recordings/Pilot_Data_XLMAN/Imp_20240314/Recordings/
# Out:
# /nas/Neuropixel2_Recordings/Pilot_Data_XLMAN/Imp_20240314/Recordings
# /home/eduarda/.virtualenvs/SI-0_100_2/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
rec = si.read_spikeglx(folder_path='20240314_LMANXbottom_200microA_e1_g0', stream_id='imec0.ap')

# %%
rec_preproc = si.bandpass_filter(rec)

si.plot_traces(rec_preproc, backend='ipywidgets', order_channel_by_depth=True)
# Out:
# AppLayout(children=(TimeSlider(children=(Dropdown(description='segment', options=(0,), value=0), Button(icon='…

# %%
cmed = si.common_reference(rec_preproc, 
                           local_radius= (50, 100), 
                           reference= "local"
                           )

si.plot_traces(cmed, backend='ipywidgets', order_channel_by_depth=True)
# Out:
# AppLayout(children=(TimeSlider(children=(Dropdown(description='segment', options=(0,), value=0), Button(icon='…
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~/.virtualenvs/SI-0_100_2/lib/python3.10/site-packages/ipywidgets/widgets/widget.py:773, in Widget._handle_msg(self, msg)
#     771         if 'buffer_paths' in data:
#     772             _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 773         self.set_state(state)
#     775 # Handle a state request.
#     776 elif method == 'request_state':
#
# File ~/.virtualenvs/SI-0_100_2/lib/python3.10/site-packages/ipywidgets/widgets/widget.py:650, in Widget.set_state(self, sync_data)
#     645         self._send(msg, buffers=echo_buffers)
#     647 # The order of these context managers is important. Properties must
#     648 # be locked when the hold_trait_notification context manager is
# ...
